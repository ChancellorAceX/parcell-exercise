# %%
import re
import requests
url = 'https://ftis.org/'

# %%
response = requests.get(url+'Posts.aspx')
if response.status_code == 200:
    print('response received')
    data = response.text
else:
    print(f'Failed to get: {response.status_code}')
# Out:
# response received

# %%
Titles = re.findall(r'(?<=\d_lb_name">).+(?=</span>)', data)
print(Titles)
# Out:
# ['Area Regional Transit of St. Lucie County (SLCART)', 'Baker County Council on Aging', 'Bayway', 'Big Bend Transit', 'Breeze Transit', 'Broward County Transit', 'Central Florida Regional Transportation Authority, dba: LYNX', 'Citrus County Transit ', 'Collier Area Transit', 'County of Volusia, dba: VOTRAN', 'DeSoto Arcadia Regional Transit', 'Emerald Coast Rider', 'Escambia County Area Transit', 'Florida Rural Agencies', 'Gainesville Regional Transit System  \t', 'Hendry County Transit System', 'Hernando County Transit', 'Hillsborough Area Regional Transit', 'Indian River Transit Go Line', 'Jacksonville Transportation Authority', 'Key West Transit', 'Lake County Transit', 'Lakeland Area Mass Transit District,  dba: Citrus Connection', 'Lee County Transit', 'Manatee County Area Transit', 'Marion Transit', 'Martin County Transit Service', 'Miami-Dade Transit', 'Palm Tran', 'Pasco County Public Transportation', 'Pinellas Suncoast Transit Authority', 'Ride Solution, Inc.', 'South Florida Regional Transportation Authority (SFRTA), dba: Tri-Rail', 'South Florida Trolleys/Community Buses/Shuttles', 'Space Coast Area Transit', 'St. Johns County Public Bus Service', 'St. Lucie Treasure Coast Connector', 'StarMetro', 'Sumter County Transit', 'SunRail', 'SunTran']

# %%
IDs = re.findall(r'(?<=javascript:return DownloadFile\(&quot;).+(?=&quot;\))', data)
print(IDs)
GoodIDs = []
for id in IDs:
    GoodIDs.append(id.replace('#','A'))
print(GoodIDs)
# Out:
# ['977#0', '954#0', '953#0', '1032#0', '1016#0', '1012#0', '861#0', '809#0', '785#0', '776#0', '765#0', '752#0', '712#0', '694#0', '650#0', '624#0', '623#0', '590#0', '591#0', '585#0', '584#0', '562#0', '559#0', '550#0', '532#0', '521#0', '497#0', '496#0', '470#0', '451#0', '417#0', '398#0', '397#0', '372#0', '317#0', '295#0', '239#0', '208#0', '172#0', '154#0', '155#0', '101#0', '956#0', '955#0', '1004#0', '1000#0', '930#0', '838#0', '784#0', '775#0', '722#0', '711#0', '682#0', '659#0', '622#0', '603#0', '457#0', '446#0', '412#0', '355#0', '354#0', '326#0', '291#0', '258#0', '257#0', '219#0', '175#0', '177#0', '150#0', '134#0', '1022#0', '1005#0', '996#0', '943#0', '914#0', '873#0', '871#0', '870#0', '869#0', '868#0', '860#0', '850#0', '830#0', '812#0', '806#0', '794#0', '777#0', '755#0', '754#0', '753#0', '723#0', '695#0', '684#0', '671#0', '661#0', '660#0', '625#0', '610#0', '592#0', '583#0', '563#0', '551#0', '533#0', '522#0', '498#0', '483#0', '469#0', '452#0', '453#0', '438#0', '430#0', '404#0', '385#0', '379#0', '368#0', '362#0', '363#0', '361#0', '318#0', '296#0', '287#0', '282#0', '281#0', '210#0', '119#0', '96#0', '1049#0', '1045#0', '1047#0', '1046#0', '1048#0', '1024#0', '995#0', '976#0', '
866A0', '867A0', '865A0', '856A0', '818A0', '819A0', '796A0', '767A0', '701A0', '667A0', '651A0', '644A0', '602A0', '574A0', '575A0', '561A0', '540A0', '513A0', '507A0', '477A0', '468A0', '456A0', '428A0', '411A0', '357A0', '358A0', '356A0', '325A0', '305A0', '256A0', '215A0', '171A0', '170A0', '110A0', '960A0', '959A0', '1010A0', '195A0', '142A0', '104A0', '1060A0', '1059A0', '1054A0', '1007A0', '1003A0', '941A0', '933A0', '910A0', '876A0', '874A0', '848A0', '814A0', '797A0', '787A0', '768A0', '757A0', '746A0', '737A0', '725A0', '702A0', '678A0', '662A0', '652A0', '629A0', '628A0', '627A0', '621A0', '620A0', '597A0', '566A0', '565A0', '534A0', '514A0', '499A0', '484A0', '480A0', '460A0', '455A0', '439A0', '431A0', '426A0', '408A0', '400A0', '381A0', '373A0', '334A0', '335A0', '336A0', '333A0', '310A0', '300A0', '284A0', '274A0', '272A0', '273A0', '242A0', '241A0', '216A0', '167A0', '166A0', '165A0', '120A0', '99A0', '920A0', '693A0', '125A0', '1027A0', '970A0', '875A0', '840A0', '798A0', '756A0', '738A0', '727A0', '726A0', '630A0', '573A0', '535A0', '500A0', '471A0', '440A0', '418A0', '401A0', '374A0', '338A0', '337A0', '319A0', '301A0', '285A0', '244A0', '243A0', '203A0', '169A0', '168A0', '121A0', '962A0', '961A0', '993A0', '986A0', '985A0', '9 ...

# %%
print(len(GoodIDs),len(Titles))
# Out:
# 885 41

# %%
links = []
for id in GoodIDs:
    links.append(url+'PostFileDownload.aspx?id='+id)
print(links)
# Out:
# ['https://ftis.org/PostFileDownload.aspx?id=977A0', 'https://ftis.org/PostFileDownload.aspx?id=954A0', 'https://ftis.org/PostFileDownload.aspx?id=953A0', 'https://ftis.org/PostFileDownload.aspx?id=1032A0', 'https://ftis.org/PostFileDownload.aspx?id=1016A0', 'https://ftis.org/PostFileDownload.aspx?id=1012A0', 'https://ftis.org/PostFileDownload.aspx?id=861A0', 'https://ftis.org/PostFileDownload.aspx?id=809A0', 'https://ftis.org/PostFileDownload.aspx?id=785A0', 'https://ftis.org/PostFileDownload.aspx?id=776A0', 'https://ftis.org/PostFileDownload.aspx?id=765A0', 'https://ftis.org/PostFileDownload.aspx?id=752A0', 'https://ftis.org/PostFileDownload.aspx?id=712A0', 'https://ftis.org/PostFileDownload.aspx?id=694A0', 'https://ftis.org/PostFileDownload.aspx?id=650A0', 'https://ftis.org/PostFileDownload.aspx?id=624A0', 'https://ftis.org/PostFileDownload.aspx?id=623A0', 'https://ftis.org/PostFileDownload.aspx?id=590A0', 'https://ftis.org/PostFileDownload.aspx?id=591A0', 'https://ftis.org/PostFileDownload.aspx?id=585A0', 'https://ftis.org/PostFileDownload.aspx?id=584A0', 'https://ftis.org/PostFileDownload.aspx?id=562A0', 'https://ftis.org/PostFileDownload.aspx?id=559A0', 'https://ftis.org/PostFileDownload.aspx?id=550A0', 'https://ftis.org/PostFileDownload.aspx?id=532A0', 'https://ftis.org/PostFileDownload.aspx?id=521A0', 'https://ftis.org/PostFileDownload.aspx?id=497A0', 'https://ftis.org/PostFileDownload.aspx?id=496A0', 'https://ftis.org/PostFileDownload.aspx?id=470A0', 'https://ftis.org/PostFileDownload.aspx?id=451A0', 'https://ftis.org/PostFileDownload.aspx?id=417A0', 'https://ftis.org/PostFileDownload.aspx?id=398A0', 'https://ftis.org/PostFileDownload.aspx?id=397A0', 'https://ftis.org/PostFileDownload.aspx?id=372A0', 'https://ftis.org/PostFileDownload.aspx?id=317A0', 'https://ftis.org/PostFileDownload.aspx?id=295A0', 'https://ftis.org/PostFileDownload.aspx?id=239A0', 'https://ftis.org/PostFileDownload.aspx?id=208A0', 'https://ftis.org/PostFileDownload.aspx?id=172A0', 'https://ftis.org/PostFileDownload.aspx?id=154A0', 'https://ftis.org/PostFileDownload.aspx?id=155A0', 'https://ftis.org/PostFileDownload.aspx?id=101A0', 'https://ftis.org/PostFileDownload.aspx?id=956A0', 'https://ftis.org/PostFileDownload.aspx?id=955A0', 'https://ftis.org/PostFileDownload.aspx?id=1004A0', 'https://ftis.org/PostFileDownload.aspx?id=1000A0', 'https://ftis.org/PostFileDownload.aspx?id=930A0', 'https://ftis.org/PostFileDownload.aspx?id=838A0', 'https://ftis.org/PostFileDownload.aspx?id=784A0', 'https://ftis.org/PostFileDownload.aspx?id=775A0', 'https://ftis.org/PostFileDownload.aspx?id=722A0', 'https://ftis.org/PostFileDownload.aspx?id=711A0', 'https://ftis.org/PostFileDownload.aspx?id=682A0', 'https://ftis.org/PostFileDownload.aspx?id=659A0', 'https://ftis.org/PostFileDownload.aspx?id=622A0', 'https://ftis.org/PostFileDownload.aspx?id=603A0', 'https://ftis.org/PostFileDownload.aspx?id=457A0', 'https://ftis.org/PostFileDownload.aspx?id=446A0', 'https://ftis.org/PostFileDownload.aspx?id=412A0', 'https://ftis.org/PostFileDownload.aspx?id=355A0', 'https://ftis.org/PostFileDownload.aspx?id=354A0', 'https://ftis.org/PostFileDownload.aspx?id=326A0', 'https://ftis.org/PostFileDownload.aspx?id=291A0', 'https://ftis.org/PostFileDownload.aspx?id=258A0', 'https://ftis.org/PostFileDownload.aspx?id=257A0', 'https://ftis.org/PostFileDownload.aspx?id=219A0', 'https://ftis.org/PostFileDownload.aspx?id=175A0', 'https://ftis.org/PostFileDownload.aspx?id=177A0', 'https://ftis.org/PostFileDownload.aspx?id=150A0', 'https://ftis.org/PostFileDownload.aspx?id=134A0', 'https://ftis.org/PostFileDownload.aspx?id=1022A0', 'https://ftis.org/PostFileDownload.aspx?id=1005A0', 'https://ftis.org/PostFileDownload.aspx?id=996A0', 'https://ftis.org/PostFileDownload.aspx?id=943A0', 'https://ftis.org/PostFileDownload.aspx?id=914A0', 'https://ftis.org/PostFileDownload.aspx?id=873A0', 'https://ftis.org/PostFileDownload.aspx?id=871A0', 'https://ftis.org/PostFileDownload.aspx?id=870A0', 'https://ftis. ...

# %%
# TIME LIMIT SEPARATOR

# %%
pos = re.finditer('lessons',data)
indeces = []
for val in pos:
  indeces.append(val.start())
indeces=indeces[1:]

counts = [0]
pattern = re.compile(r'javascript:return DownloadFile')
for index, val in enumerate(indeces):
  if index == len(indeces)-1:
    count = len(pattern.findall(data,val))
  else:
    count = len(pattern.findall(data,val,indeces[index+1]))
  counts.append(count)

dictionary = {}
for n, t in enumerate(Titles):
  dictionary[t]=links[counts[n]:sum(counts[0:n+2])]

print(dictionary)
# Out:
# {'Area Regional Transit of St. Lucie County (SLCART)': ['https://ftis.org/PostFileDownload.aspx?id=977A0'], 'Baker County Council on Aging': ['https://ftis.org/PostFileDownload.aspx?id=954A0', 'https://ftis.org/PostFileDownload.aspx?id=953A0'], 'Bayway': ['https://ftis.org/PostFileDownload.aspx?id=953A0', 'https://ftis.org/PostFileDownload.aspx?id=1032A0', 'https://ftis.org/PostFileDownload.aspx?id=1016A0', 'https://ftis.org/PostFileDownload.aspx?id=1012A0', 'https://ftis.org/PostFileDownload.aspx?id=861A0', 'https://ftis.org/PostFileDownload.aspx?id=809A0', 'https://ftis.org/PostFileDownload.aspx?id=785A0', 'https://ftis.org/PostFileDownload.aspx?id=776A0', 'https://ftis.org/PostFileDownload.aspx?id=765A0', 'https://ftis.org/PostFileDownload.aspx?id=752A0', 'https://ftis.org/PostFileDownload.aspx?id=712A0', 'https://ftis.org/PostFileDownload.aspx?id=694A0', 'https://ftis.org/PostFileDownload.aspx?id=650A0', 'https://ftis.org/PostFileDownload.aspx?id=624A0', 'https://ftis.org/PostFileDownload.aspx?id=623A0', 'https://ftis.org/PostFileDownload.aspx?id=590A0', 'https://ftis.org/PostFileDownload.aspx?id=591A0', 'https://ftis.org/PostFileDownload.aspx?id=585A0', 'https://ftis.org/PostFileDownload.aspx?id=584A0', 'https://ftis.org/PostFileDownload.aspx?id=562A0', 'https://ftis.org/PostFileDownload.aspx?id=559A0', 'https://ftis.org/PostFileDownload.aspx?id=550A0', 'https://ftis.org/PostFileDownload.aspx?id=532A0', 'https://ftis.org/PostFileDownload.aspx?id=521A0', 'https://ftis.org/PostFileDownload.aspx?id=497A0', 'https://ftis.org/PostFileDownload.aspx?id=496A0', 'https://ftis.org/PostFileDownload.aspx?id=470A0', 'https://ftis.org/PostFileDownload.aspx?id=451A0', 'https://ftis.org/PostFileDownload.aspx?id=417A0', 'https://ftis.org/PostFileDownload.aspx?id=398A0', 'https://ftis.org/PostFileDownload.aspx?id=397A0', 'https://ftis.org/PostFileDownload.aspx?id=372A0', 'https://ftis.org/PostFileDownload.aspx?id=317A0', 'https://ftis.org/PostFileDownload.aspx?id=295A0', 'https://ftis.org/PostFileDownload.aspx?id=239A0', 'https://ftis.org/PostFileDownload.aspx?id=208A0', 'https://ftis.org/PostFileDownload.aspx?id=172A0', 'https://ftis.org/PostFileDownload.aspx?id=154A0', 'https://ftis.org/PostFileDownload.aspx?id=155A0', 'https://ftis.org/PostFileDownload.aspx?id=101A0'], 'Big Bend Transit': ['https://ftis.org/PostFileDownload.aspx?id=154A0', 'https://ftis.org/PostFileDownload.aspx?id=155A0', 'https://ftis.org/PostFileDownload.aspx?id=101A0', 'https://ftis.org/PostFileDownload.aspx?id=956A0', 'https://ftis.org/PostFileDownload.aspx?id=955A0'], 'Breeze Transit': ['https://ftis.org/PostFileDownload.aspx?id=953A0', 'https://ftis.org/PostFileDownload.aspx?id=1032A0', 'https://ftis.org/PostFileDownload.aspx?id=1016A0', 'https://ftis.org/PostFileDownload.aspx?id=1012A0', 'https://ftis.org/PostFileDownload.aspx?id=861A0', 'https://ftis.org/PostFileDownload.aspx?id=809A0', 'https://ftis.org/PostFileDownload.aspx?id=785A0', 'https://ftis.org/PostFileDownload.aspx?id=776A0', 'https://ftis.org/PostFileDownload.aspx?id=765A0', 'https://ftis.org/PostFileDownload.aspx?id=752A0', 'https://ftis.org/PostFileDownload.aspx?id=712A0', 'https://ftis.org/PostFileDownload.aspx?id=694A0', 'https://ftis.org/PostFileDownload.aspx?id=650A0', 'https://ftis.org/PostFileDownload.aspx?id=624A0', 'https://ftis.org/PostFileDownload.aspx?id=623A0', 'https://ftis.org/PostFileDownload.aspx?id=590A0', 'https://ftis.org/PostFileDownload.aspx?id=591A0', 'https://ftis.org/PostFileDownload.aspx?id=585A0', 'https://ftis.org/PostFileDownload.aspx?id=584A0', 'https://ftis.org/PostFileDownload.aspx?id=562A0', 'https://ftis.org/PostFileDownload.aspx?id=559A0', 'https://ftis.org/PostFileDownload.aspx?id=550A0', 'https://ftis.org/PostFileDownload.aspx?id=532A0', 'https://ftis.org/PostFileDownload.aspx?id=521A0', 'https://ftis.org/PostFileDownload.aspx?id=497A0', 'https://ftis.org/PostFileDownload.aspx?id=496A0', 'https://ftis.org/PostFileDownload.aspx?id=470A0', 'https://ftis.org/PostFi ...

# %%
import json

with open('config.json','w') as f:
  json.dump(dictionary,f,indent=4)

with open('config.json','r') as f:
  loaded_config =json.load(f)

print(loaded_config)
# Out:
# {'Area Regional Transit of St. Lucie County (SLCART)': ['https://ftis.org/PostFileDownload.aspx?id=977A0'], 'Baker County Council on Aging': ['https://ftis.org/PostFileDownload.aspx?id=954A0', 'https://ftis.org/PostFileDownload.aspx?id=953A0'], 'Bayway': ['https://ftis.org/PostFileDownload.aspx?id=953A0', 'https://ftis.org/PostFileDownload.aspx?id=1032A0', 'https://ftis.org/PostFileDownload.aspx?id=1016A0', 'https://ftis.org/PostFileDownload.aspx?id=1012A0', 'https://ftis.org/PostFileDownload.aspx?id=861A0', 'https://ftis.org/PostFileDownload.aspx?id=809A0', 'https://ftis.org/PostFileDownload.aspx?id=785A0', 'https://ftis.org/PostFileDownload.aspx?id=776A0', 'https://ftis.org/PostFileDownload.aspx?id=765A0', 'https://ftis.org/PostFileDownload.aspx?id=752A0', 'https://ftis.org/PostFileDownload.aspx?id=712A0', 'https://ftis.org/PostFileDownload.aspx?id=694A0', 'https://ftis.org/PostFileDownload.aspx?id=650A0', 'https://ftis.org/PostFileDownload.aspx?id=624A0', 'https://ftis.org/PostFileDownload.aspx?id=623A0', 'https://ftis.org/PostFileDownload.aspx?id=590A0', 'https://ftis.org/PostFileDownload.aspx?id=591A0', 'https://ftis.org/PostFileDownload.aspx?id=585A0', 'https://ftis.org/PostFileDownload.aspx?id=584A0', 'https://ftis.org/PostFileDownload.aspx?id=562A0', 'https://ftis.org/PostFileDownload.aspx?id=559A0', 'https://ftis.org/PostFileDownload.aspx?id=550A0', 'https://ftis.org/PostFileDownload.aspx?id=532A0', 'https://ftis.org/PostFileDownload.aspx?id=521A0', 'https://ftis.org/PostFileDownload.aspx?id=497A0', 'https://ftis.org/PostFileDownload.aspx?id=496A0', 'https://ftis.org/PostFileDownload.aspx?id=470A0', 'https://ftis.org/PostFileDownload.aspx?id=451A0', 'https://ftis.org/PostFileDownload.aspx?id=417A0', 'https://ftis.org/PostFileDownload.aspx?id=398A0', 'https://ftis.org/PostFileDownload.aspx?id=397A0', 'https://ftis.org/PostFileDownload.aspx?id=372A0', 'https://ftis.org/PostFileDownload.aspx?id=317A0', 'https://ftis.org/PostFileDownload.aspx?id=295A0', 'https://ftis.org/PostFileDownload.aspx?id=239A0', 'https://ftis.org/PostFileDownload.aspx?id=208A0', 'https://ftis.org/PostFileDownload.aspx?id=172A0', 'https://ftis.org/PostFileDownload.aspx?id=154A0', 'https://ftis.org/PostFileDownload.aspx?id=155A0', 'https://ftis.org/PostFileDownload.aspx?id=101A0'], 'Big Bend Transit': ['https://ftis.org/PostFileDownload.aspx?id=154A0', 'https://ftis.org/PostFileDownload.aspx?id=155A0', 'https://ftis.org/PostFileDownload.aspx?id=101A0', 'https://ftis.org/PostFileDownload.aspx?id=956A0', 'https://ftis.org/PostFileDownload.aspx?id=955A0'], 'Breeze Transit': ['https://ftis.org/PostFileDownload.aspx?id=953A0', 'https://ftis.org/PostFileDownload.aspx?id=1032A0', 'https://ftis.org/PostFileDownload.aspx?id=1016A0', 'https://ftis.org/PostFileDownload.aspx?id=1012A0', 'https://ftis.org/PostFileDownload.aspx?id=861A0', 'https://ftis.org/PostFileDownload.aspx?id=809A0', 'https://ftis.org/PostFileDownload.aspx?id=785A0', 'https://ftis.org/PostFileDownload.aspx?id=776A0', 'https://ftis.org/PostFileDownload.aspx?id=765A0', 'https://ftis.org/PostFileDownload.aspx?id=752A0', 'https://ftis.org/PostFileDownload.aspx?id=712A0', 'https://ftis.org/PostFileDownload.aspx?id=694A0', 'https://ftis.org/PostFileDownload.aspx?id=650A0', 'https://ftis.org/PostFileDownload.aspx?id=624A0', 'https://ftis.org/PostFileDownload.aspx?id=623A0', 'https://ftis.org/PostFileDownload.aspx?id=590A0', 'https://ftis.org/PostFileDownload.aspx?id=591A0', 'https://ftis.org/PostFileDownload.aspx?id=585A0', 'https://ftis.org/PostFileDownload.aspx?id=584A0', 'https://ftis.org/PostFileDownload.aspx?id=562A0', 'https://ftis.org/PostFileDownload.aspx?id=559A0', 'https://ftis.org/PostFileDownload.aspx?id=550A0', 'https://ftis.org/PostFileDownload.aspx?id=532A0', 'https://ftis.org/PostFileDownload.aspx?id=521A0', 'https://ftis.org/PostFileDownload.aspx?id=497A0', 'https://ftis.org/PostFileDownload.aspx?id=496A0', 'https://ftis.org/PostFileDownload.aspx?id=470A0', 'https://ftis.org/PostFi ...
